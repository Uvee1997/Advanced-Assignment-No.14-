# %% [markdown]
# 1) Is an assignment operator like += only for show? Is it possible that it would lead to faster results
#    at the runtime?
#
# :- No. This assignment operators are used for add the value on it's right to the variable or properties on it's left,
#    & assigns result to the variable or property on it's left. Yes it will result faster and in better way.

# %% [markdown]
# 2) What is the smallest number of statements you'd have to write in most programming languages to replace
#    the Python expression a, b = a + b, a?
#
# :- Namely,break,continue & pass statement are used the most.

# %% [markdown]
# 3) In python, what is the most effective way to set list 100 integer to 0?
#
# :- list(rang(101,0))

# %% [markdown]
# 4) If you're using IDLE to run a Python application, explain how to print a multidimensional list as efficiently?
#
# :- Accessing with the help of loop.
#    Accessing using square brackets.
#    Adds an element at the end of the list
#    Add the elements of a list or any iterable, to the end of the current list.
#    Reverses the order of list.

# %% [markdown]
# 5) Is it possible to use list comprehension with a string? If so, how can you go about doing it?
#
# :- It can be identify when it receives a string or tuple and work on it like list. You can do that by using loop.
#    However every loop can not be written as list comprehension. But as you learn & get more comfortable with list
#    comprehension, you will find yourself more & more loops with this elegant syntax.

# %%
6) From the command line, how do you get support with a user-written Python programme? Is this possible from IDLE?

:- IDLE is Python’s Integrated Development and Learning Environment. This possible by IDLE as it is 100% coded in 
    python

# %% [markdown]
# 7) Functions are said to be “first-class objects” in Python but not in most other languages, such as
#    C++ or Java. What can you do in Python with a function (callable object) that you can't do in C or C++?
#
# :- spam.system(string)

# %% [markdown]
# 8) How do you distinguish between a wrapper, a wrapped feature, and a decorator?
#
# :- Decorators allow us to wrap another function in order to extend the behavior of the wrapped function, without permanently modifying it. In Decorators, functions are taken as the argument into
#    another function and then called inside the wrapper function.

# %% [markdown]
# 9) If a function is a generator function, what does it return?
#
# :- object(iterator)

# %% [markdown]
# 10) What is the one improvement that must be made to a function in order for it to become a generator function in the
#     Python language?
#
# :- It may have at least one yield statement. If it contain other statement or return statement, it becomes generator
#    function

# %% [markdown]
# 11) Identify atleast one benefit of generator.
#
# :- It allows you to declare a function that behaves like an iterator.
#    Memory efficient method of generating sequence type in python.
